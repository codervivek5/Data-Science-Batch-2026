# %%
import pandas as pd
import numpy as np

# %%
mydata = {
    "car":["bmw","audi","innova"],
    "price":[120000,240000,43000]
}

# %%
df = pd.DataFrame(mydata)

# %%
df.loc[[0,1]]

# %%
a = [1,2,7]
mydata = pd.Series(a,index=["x","y","z"])

# %%
print(mydata["y"])

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)

print(df)

# %%
df2 = pd.read_csv(r'/Users/codervivek/Desktop/Data Science Batch 2026/ML Practice/data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2612941314.py in <cell line: 0>()
# ----> 1 df2 = pd.read_csv(r'/Users/codervivek/Desktop/Data Science Batch 2026/ML Practice/data.csv')
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']
